# %%
import pandas as pd
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
#from myplot import plot_verticles

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
expected_losses=pd.read_csv("expected_losses.csv")

# %% [markdown]
# A scatter plot of expected losses and strategies for Mr. Nelson

# %%
ax = plt.axes(projection='3d')
zdata = expected_losses.iloc[2]
xdata = expected_losses.iloc[0]
ydata = expected_losses.iloc[1]
ax.scatter3D(xdata, ydata, zdata);

# %% [markdown]
# A movable plot of the convex set of all strategies and their expected losses for Mr. Nelson

# %%
import plotly.graph_objects as go
import numpy as np

# Download data set from plotly repo


fig = go.Figure(data=[go.Mesh3d(x=xdata, y=ydata, z=zdata, color='lightpink', opacity=0.80)])
fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
r = 0.05
u, v = np.mgrid[0:2 * np.pi:30j, 0:np.pi:20j]
x = np.cos(u) * np.sin(v)
y = np.sin(u) * np.sin(v)
z = np.cos(v)
ax.plot_surface(x, y, z)
plt.show()

# %%
fig = go.Figure(data=[go.Surface(z=z, x=x, y=y)])
fig.show()
